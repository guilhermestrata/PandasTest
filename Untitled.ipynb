# %%
pip install pandas pyodbc
# Out:
# ...
#                                               0.0/10.6 MB ? eta -:--:--
#                                               0.0/10.6 MB ? eta -:--:--
#                                              0.0/10.6 MB 325.1 kB/s eta 0:00:33
#                                              0.1/10.6 MB 409.6 kB/s eta 0:00:26
#                                              0.1/10.6 MB 409.6 kB/s eta 0:00:26
#                                              0.1/10.6 MB 409.6 kB/s eta 0:00:26
#                                              0.1/10.6 MB 409.6 kB/s eta 0:00:26
#                                              0.1/10.6 MB 409.6 kB/s eta 0:00:26
#                                              0.1/10.6 MB 409.6 kB/s eta 0:00:26
#                                              0.1/10.6 MB 409.6 kB/s eta 0:00:26
#                                              0.1/10.6 MB 409.6 kB/s eta 0:00:26
#                                              0.1/10.6 MB 409.6 kB/s eta 0:00:26
# ...

# %%
pip install openpyxl
# Out:
# ...
#                                               0.0/250.0 kB ? eta -:--:--
#      ---------------------------------------- 250.0/250.0 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Python311\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import pyodbc
import openpyxl

# %%
df = pd.read_excel('dados.xlsx')

# %%
df.Nome.loc[df.Nome == 'Olivia Jensen']
# Out:
# 0    Olivia Jensen
# Name: Nome, dtype: object

# %%
df.columns.to_list()
# Out:
# ['Nome', 'Idade', 'Email', 'CPF', 'CEP', 'Pai', 'Mae']

# %%
import pyodbc
import pandas as pd

server = 'localhost'
database = 'pandastest'
username = 'sa'
password = 'fiap'

connection = pyodbc.connect(f'DRIVER=SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password}')
cursor = connection.cursor()

for index, row in df.iterrows():
    cursor.execute("INSERT INTO Pessoas (Idade, Email, CPF, CEP, Pai, Mae) VALUES (?, ?, ?, ?, ?, ?)",
                   row.Idade, row.Email, row.CPF, row.CEP, row.Pai, row.Mae)
connection.commit()
cursor.close()
